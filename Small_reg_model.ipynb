# %% [markdown]
# <a href="https://colab.research.google.com/github/Quntized/Image-Compression-/blob/main/Small_reg_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams['figure.figsize'] = [8,8]
plt.rcParams.update({'font.size':18})

# %%
x = 3 #true slop
a = np.arange(-2,2,0.1)
a= a.reshape(-1,1)
b = x*a + np.random.randn(*a.shape)
plt.plot(a,x*a,color='k',linewidth =2,label ='True line')
plt.plot(a,b,'x',color='r',markersize=10,label='noisy data')
U,S,VT = np.linalg.svd(a,full_matrices = False)
x_tilda = VT.T @ np.linalg.inv(np.diag(S)) @ U.T @ b
plt.plot(a,x_tilda*a,'--',color='b',linewidth=4,label='regression line' )
plt.xlabel('a')
plt.ylabel('b')
plt.grid(linestyle='--')
plt.legend()
plt.show()

# %%
x_tilda
# Out:
# array([[2.90681201]])

# %%
x_tilda2 = np.linalg.pinv(a)@b

# %%
x_tilda2
# Out:
# array([[2.90681201]])

# %% [markdown]
# I can do exactly same thing that is given in x_tilda2 . Actually x_tilda and x_tilda2 are exactly the same thing
