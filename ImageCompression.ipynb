# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import os
plt.rcParams['figure.figsize'] = [16,8]

# %%
A = imread('C:\\Users\\sk006\\Downloads\\dog.jpg')
x = np.mean(A,-1) #convert from RGB to greyscale

# %%
img = plt.imshow(x)
plt.set_cmap('gray')
plt.axis('off')
plt.show()

# %%
U,S,VT = np.linalg.svd(x,full_matrices =False)
S = np.diag(S)

# %%
S.shape
# Out:
# (355, 355)

# %%
#I wanna see how how good the r approximation of singular value decomposition
j=0
for r in (5,20,100):
    #construct approximate image
    Xapproax = U[:,:r] @ S[0:r,:r] @ VT[:r,:]
    plt.figure(j+1)
    j+=1
    img = plt.imshow(Xapproax)
    img.set_cmap('gray')
    plt.axis('off')
    plt.title('r = '+str(r))
    plt.show()

# %%
plt.figure(1)
plt.semilogy(np.diag(S))
plt.title('Singular Values')
plt.show()

plt.figure(2)
plt.plot(np.cumsum(np.diag(S)/np.sum(np.diag(S))))
plt.title('Singular values cumulative sum')
plt.show()

# %% [markdown]
# **There's a lot of energy captured by few modes or i can say in first small number the singular value all of it's essence is captured . We can see from both of these graph , very helpful to understand the topic **

# %% [markdown]
# ** I can keep first range in x axis's singular value and the last values doesn't contribute much and i can compressed the image efficiently**
